# %%
import requests
import pandas as pd

# %%
def main():
    offset = 0
    while True:
        url = 'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset=5&limit=100&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
        params = (
            ('offset', offset),
            ('limit', 100),
            ('sortField', 'devShortNm'),
            ('sortType', 'asc')
        )
        res = requests.get(url, params=params)
        objects_data = res.json()
        
        obj = objects_data['data']['list']
        
        for developer in obj:
            devId = developer['devId']
            shortName = developer['shortName']
        
        data: {'devId': devId,
               'shortName': shortName
            }
        print(data)
            

        if not obj:
            break
        offset += 100
        break

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-128-dd856dc2bfe8> in main()
#      15
#      16         for developer in obj:
# ---> 17             devId = developer['devId']
#      18             shortName = developer['shortName']
#      19
#
# KeyError: 'devId'

# %%
objects_data.get('data').get('list')[6]

# %%
offset_ = 1
limit_ = 100
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
# Out:
# {'objId': 29678,
#  'developer': {'devId': 7424,
#   'shortName': '212-2',
#   'fullName': '212-2',
#   'orgForm': {'id': 20,
#    'fullForm': 'Жилищный или жилищно-строительный кооператив',
#    'shortForm': 'ЖСК'},
#   'devInn': '6154572922'},
#  'rpdRegionCd': 61,
#  'objAddr': 'город Таганрог, улица Сергея Шило, д. 212-2',
#  'objElemLivingCnt': 27,
#  'objReady100PercDt': '2020-03-31',
#  'objSquareLiving': 1519.0,
#  'objCompensFundFlg': 0,
#  'objProblemFlg': 0,
#  'latitude': 47.2197,
#  'longitude': 38.9134,
#  'problemFlag': 'NONE',
#  'siteStatus': 'Строящиеся',
#  'objGuarantyEscrowFlg': 0,
#  'residentialBuildings': 1,
#  'rpdNum': '61-000819',
#  'pdId': 124648,
#  'buildType': 'Жилое',
#  'objStatus': 0}

# %%
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:28]
# Out:
# [29678,
#  13383,
#  13397,
#  13399,
#  13398,
#  13391,
#  36912,
#  44076,
#  23494,
#  27476,
#  10891,
#  39176,
#  39174,
#  39175,
#  27049,
#  41421,
#  41420,
#  30292,
#  19414,
#  19457,
#  18708,
#  18709,
#  21534,
#  21536,
#  21535,
#  21537,
#  41625,
#  42192]

# %%
with open('1.webm', 'wb') as fd:
    for

# %%
df = pd.DataFrame(objects_data)
df.info
# Out:
# <bound method DataFrame.info of                                                     data errcode
# list   [{'objId': 29678, 'developer': {'devId': 7424,...       0
# total                                              10528       0>

# %%
print(df.to_csv())
# Out:
# ,data,errcode
# ...
